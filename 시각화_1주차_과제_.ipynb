# %% [markdown]
# # 1주차 멘멘 스터디 시각화 과제
# 대부분 오늘 세션을 통해 해결할 수 있습니다. 안 배운 부분이 있다면 구글링을 해서 문제를 풀어보세요!
#
# 앞으로 구글링은 떼려야 뗄 수 없는 관계이므로,,,ㅎ 구글링 잘하는 것도 중요합니다! 그래도 풀리지 않는 문제는 빈칸으로 제출해도 좋아요:)

# %% [markdown]
# ### 데이터 훑어보기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# 01. train.csv 파일을 데이터프레임으로 읽기
train = pd.read_csv("/content/drive/MyDrive/Boaz/train.csv")

# %%
# 02. 학습 데이터 셋의 상위 5개 항목 출력
train.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y
# 0 -122.425892  37.774599
# 1 -122.425892  37.774599
# 2 -122.424363  37.800414
# 3 -122.426995  37.800873
# ...

# %%
# 03. 학습 데이터 셋의 각 필드 기술 통계 요약(평균, 최소값, 최대값 등)을 살펴보기
train.describe()
# Out:
#                    X              Y
# count  878049.000000  878049.000000
# mean     -122.422616      37.771020
# std         0.030354       0.456893
# min      -122.513642      37.707879
# 25%      -122.432952      37.752427
# 50%      -122.416420      37.775421
# 75%      -122.406959      37.784369
# max      -120.500000      90.000000

# %%
# 04. 각 컬럼의 데이터 타입 확인하기
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878049 entries, 0 to 878048
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Dates       878049 non-null  object
#  1   Category    878049 non-null  object
#  2   Descript    878049 non-null  object
#  3   DayOfWeek   878049 non-null  object
#  4   PdDistrict  878049 non-null  object
#  5   Resolution  878049 non-null  object
#  6   Address     878049 non-null  object
#  7   X           878049 non-null  float64
#  8   Y           878049 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 60.3+ MB

# %%
# 05. 범죄의 범주 'Category'는 어떤 값이 있는지 확인하기
train['Category'].unique()
# Out:
# array(['WARRANTS', 'OTHER OFFENSES', 'LARCENY/THEFT', 'VEHICLE THEFT',
#        'VANDALISM', 'NON-CRIMINAL', 'ROBBERY', 'ASSAULT', 'WEAPON LAWS',
#        'BURGLARY', 'SUSPICIOUS OCC', 'DRUNKENNESS',
#        'FORGERY/COUNTERFEITING', 'DRUG/NARCOTIC', 'STOLEN PROPERTY',
#        'SECONDARY CODES', 'TRESPASS', 'MISSING PERSON', 'FRAUD',
#        'KIDNAPPING', 'RUNAWAY', 'DRIVING UNDER THE INFLUENCE',
#        'SEX OFFENSES FORCIBLE', 'PROSTITUTION', 'DISORDERLY CONDUCT',
#        'ARSON', 'FAMILY OFFENSES', 'LIQUOR LAWS', 'BRIBERY',
#        'EMBEZZLEMENT', 'SUICIDE', 'LOITERING',
#        'SEX OFFENSES NON FORCIBLE', 'EXTORTION', 'GAMBLING', 'BAD CHECKS',
#        'TREA', 'RECOVERED VEHICLE', 'PORNOGRAPHY/OBSCENE MAT'],
#       dtype=object)

# %% [markdown]
# ### 데이터 전처리

# %%
train.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y
# 0 -122.425892  37.774599
# 1 -122.425892  37.774599
# 2 -122.424363  37.800414
# 3 -122.426995  37.800873
# ...

# %%
import datetime
import pandas as pd

# %%
# 06. Dates 필드의 데이터타입을 'datetime64' 타입으로 변경하기
train['Dates'] = pd.to_datetime(train['Dates'],format = '%Y-%m-%d %H:%M:%S')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878049 entries, 0 to 878048
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Dates       878049 non-null  datetime64[ns]
#  1   Category    878049 non-null  object
#  2   Descript    878049 non-null  object
#  3   DayOfWeek   878049 non-null  object
#  4   PdDistrict  878049 non-null  object
#  5   Resolution  878049 non-null  object
#  6   Address     878049 non-null  object
#  7   X           878049 non-null  float64
#  8   Y           878049 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 60.3+ MB

# %%
# 07. 연, 월, 일, 요일, 시, 분값을 새로운 컬럼(year, month, day, dayofweek, hour, minute)을 생성해서 할당하기
## hint : dt(datetime) 함수를 이용하세요
train['year'] = train['Dates'].dt.year
train['month'] = train['Dates'].dt.month
train['day'] = train['Dates'].dt.day
train['dayofweek'] = train['Dates'].dt.dayofweek
train['hour'] = train['Dates'].dt.hour
train['minute'] = train['Dates'].dt.minute
train.head()
# Out:
#                 Dates        Category                      Descript  \
# 0 2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1 2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2 2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y  year  month  day  dayofweek  hour  minute
# 0 -122.425892  37.774599  2015      5   13          2    23      53
# ...

# %%
 # 08. 범죄가 발생한 경도, 위도 값을 나타내는 X, Y 컬럼의 값을 더한 값을 담은 'X+Y' 컬럼, X, Y의 차이 값을 담은 'X-Y' 컬럼을 생성하기
train["X+Y"] = train['X'] + train['Y']
train["X-Y"] = train['X'] - train['Y']
train.head()
# Out:
#                 Dates        Category                      Descript  \
# 0 2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1 2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2 2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y  year  month  day  dayofweek  hour  minute  \
# 0 -122.425892  37.774599  2015      5   13          2    23      53
# ...

# %%
# 09. n_days라는 컬럼을 생성하고, 일별 d-day를 계산하여 입력하기
train['n_days'] = (train['Dates'].dt.date - train['Dates'].dt.date.min()).apply(lambda x: x.days)

# %%
train.head()
# Out:
#                 Dates        Category                      Descript  \
# 0 2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1 2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2 2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4 2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y  year  month  day  dayofweek  hour  minute  \
# 0 -122.425892  37.774599  2015      5   13          2    23      53
# ...

# %%
train.year.unique()
# Out:
# array([2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005,
#        2004, 2003])

# %%
# 10. 연도별(year) 범죄 발생 횟수를 알아보기
train['year'].value_counts().sort_index()
#train.groupby('year')['Category'].value_counts()
# Out:
# 2003    73902
# 2004    73422
# 2005    70779
# 2006    69909
# 2007    68015
# 2008    70174
# 2009    69000
# 2010    66542
# 2011    66619
# 2012    71731
# 2013    75606
# 2014    74766
# 2015    27584
# Name: year, dtype: int64

# %%
# 11. 월별(month) 범죄 발생 횟수를 알아보기
## hint : groupby 혹은 value_counts 사용하세요
train['month'].value_counts().sort_index()
# Out:
# 1     73536
# 2     70813
# 3     76320
# 4     78096
# 5     79644
# 6     70892
# 7     69971
# 8     68540
# 9     71982
# 10    80274
# 11    72975
# 12    65006
# Name: month, dtype: int64

# %%
# 12. 요일별(DayOfWeek) 범죄 발생 횟수를 알아보기
train['dayofweek'].value_counts().sort_index()
# Out:
# 0    121584
# 1    124965
# 2    129211
# 3    125038
# 4    133734
# 5    126810
# 6    116707
# Name: dayofweek, dtype: int64

# %%
# 13. null값이 포함된 데이터 필드가 있는지 확인하기
print(train.isnull().sum()) # 결측치 없음
# Out:
# Dates         0
# Category      0
# Descript      0
# DayOfWeek     0
# PdDistrict    0
# Resolution    0
# Address       0
# X             0
# Y             0
# year          0
# month         0
# day           0
# dayofweek     0
# hour          0
# minute        0
# X+Y           0
# X-Y           0
# n_days        0
# dtype: int64

# %%
# 14. 'Dates','Category','Descript','DayOfWeek','Resolution' 컬럼 삭제하기
train.drop(['Dates','Category','Descript','DayOfWeek','Resolution'], axis=1,inplace=True)

# %%
train.head()
# Out:
#   PdDistrict                    Address           X          Y  year  month  \
# 0   NORTHERN         OAK ST / LAGUNA ST -122.425892  37.774599  2015      5
# 1   NORTHERN         OAK ST / LAGUNA ST -122.425892  37.774599  2015      5
# 2   NORTHERN  VANNESS AV / GREENWICH ST -122.424363  37.800414  2015      5
# 3   NORTHERN   1500 Block of LOMBARD ST -122.426995  37.800873  2015      5
# 4       PARK  100 Block of BRODERICK ST -122.438738  37.771541  2015      5
#
#    day  dayofweek  hour  minute        X+Y         X-Y  n_days
# 0   13          2    23      53 -84.651293 -160.200490    4510
# 1   13          2    23      53 -84.651293 -160.200490    4510
# 2   13          2    23      33 -84.623949 -160.224777    4510
# 3   13          2    23      30 -84.626123 -160.227868    4510
# 4   13          2    23      30 -84.667196 -160.210279    4510
